# %%
import sys
sys.path.insert(0, r'C:\Users\Gustavo\Documents\GitHub\objetos_celestes')

import preprocessamento  # Substitua 'nome_do_arquivo' pelo nome do seu arquivo sem a extensão .py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\Gustavo\Documents\GitHub\objetos_celestes')
# ----> 4 import preprocessamento
#
# ModuleNotFoundError: No module named 'preprocessamento'
